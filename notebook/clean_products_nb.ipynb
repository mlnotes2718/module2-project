# %%
import pandas as pd
import numpy as np
import os

# %%
raw_dir = os.getcwd()

# %%
filename = os.path.join(raw_dir, 'dataset', 'olist_products_dataset.csv')

# %%
df = pd.read_csv(filename)

# %%
df
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
df = df.drop(['product_name_lenght', 'product_description_lenght', 'product_photos_qty'], axis=1)

# %%
df.describe()
# Out:
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# min            0.000000           7.000000           2.000000
# 25%          300.000000          18.000000           8.000000
# 50%          700.000000          25.000000          13.000000
# 75%         1900.000000          38.000000          21.000000
# max        40425.000000         105.000000         105.000000
#
#        product_width_cm
# count      32949.000000
# mean          23.196728
# std           12.079047
# min            6.000000
# 25%           15.000000
# 50%           20.000000
# 75%           30.000000
# max          118.000000

# %%
check_nan = df.isnull().values.any()

# %%
check_nan
# Out:
# True

# %%
check_nan = df.isnull().sum().sum()
check_nan
# Out:
# 618

# %%
df = df.dropna(subset=['product_category_name'])
df
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
#        product_weight_g  product_length_cm  product_height_cm  \
# ...

# %%
check_nan = df.isnull().sum().sum()
check_nan
# Out:
# 4

# %%
df[df.isnull().any(axis=1)]
# Out:
#                             product_id product_category_name  \
# 8578  09ff539a621711667c43eba6a3bd8466                 bebes
#
#       product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 8578               NaN                NaN                NaN               NaN

# %%
df = df.dropna()
df
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
#        product_weight_g  product_length_cm  product_height_cm  \
# ...

# %%
check_nan = df.isnull().sum().sum()
check_nan
# Out:
# 0

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [product_id, product_category_name, product_weight_g, product_length_cm, product_height_cm, product_width_cm]
# Index: []

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32335  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32336  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32337  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32338  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32339  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
#        product_weight_g  product_length_cm  product_height_cm  \
# ...

# %%
filename1 = os.path.join(raw_dir, 'dataset', 'product_category_name_translation.csv')

# %%
df_name = pd.read_csv(filename1)
df_name
# Out:
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services
#
# [71 rows x 2 columns]

# %%
df_merged = df.merge(df_name, on='product_category_name', how='left')
df_merged
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32335  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32336  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32337  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32338  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32339  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
#        product_weight_g  product_length_cm  product_height_cm  \
# ...

# %%
df_merged[df_merged.isnull().any(axis=1)]
# Out:
#                              product_id  \
# 1581   0105b5323d24fc655f73052694dbbb3a
# 5703   6fd83eb3e0799b775e4f946bd66657c0
# 7176   5d923ead886c44b86845f69e50520c3e
# 7326   6727051471a0fc4a0e7737b57bff2549
# 8647   bed164d9d628cf0593003389c535c6e0
# 10822  1220978a08a6b29a202bc015b18250e9
# 13995  ae62bb0f95af63d64eae5f93dddea8d3
# 15874  1954739d84629e7323a4295812a3e0ec
# 16608  dbe520fb381ad695a7e1f2807d20c765
# 17459  c7a3f1a7f9eef146cc499368b578b884
# 18251  7afdd65f79f63819ff5bee328843fa37
# 26397  a4756663d007b0cd1af865754d08d968
# 29369  cb9d764f38ee4d0c00af64d5c388f837
#
#                                product_category_name  product_weight_g  \
# 1581                                        pc_gamer            2839.0
# 5703   portateis_cozinha_e_preparadores_de_alimentos            1200.0
# 7176   portateis_cozinha_e_preparadores_de_alimentos            1200.0
# 7326                                        pc_gamer             650.0
# ...

# %%
df_merged.loc[df_merged['product_category_name']=='pc_gamer', 'product_category_name_english'] = 'pc_gamer'

# %%
df_merged[df_merged['product_category_name_english']=='pc_gamer']
# Out:
#                              product_id product_category_name  \
# 1581   0105b5323d24fc655f73052694dbbb3a              pc_gamer
# 7326   6727051471a0fc4a0e7737b57bff2549              pc_gamer
# 16608  dbe520fb381ad695a7e1f2807d20c765              pc_gamer
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 1581             2839.0               19.0               16.0
# 7326              650.0               16.0               22.0
# 16608             800.0               18.0               22.0
#
#        product_width_cm product_category_name_english
# 1581               18.0                      pc_gamer
# 7326               20.0                      pc_gamer
# 16608              22.0                      pc_gamer

# %%
df_merged.fillna(value='portable_kitchen_and_food_preparators', inplace=True)

# %%
df_merged[df_merged.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [product_id, product_category_name, product_weight_g, product_length_cm, product_height_cm, product_width_cm, product_category_name_english]
# Index: []

# %%
df_merged[df_merged['product_category_name_english']=='portable_kitchen_and_food_preparators']
# Out:
#                              product_id  \
# 5703   6fd83eb3e0799b775e4f946bd66657c0
# 7176   5d923ead886c44b86845f69e50520c3e
# 8647   bed164d9d628cf0593003389c535c6e0
# 10822  1220978a08a6b29a202bc015b18250e9
# 13995  ae62bb0f95af63d64eae5f93dddea8d3
# 15874  1954739d84629e7323a4295812a3e0ec
# 17459  c7a3f1a7f9eef146cc499368b578b884
# 18251  7afdd65f79f63819ff5bee328843fa37
# 26397  a4756663d007b0cd1af865754d08d968
# 29369  cb9d764f38ee4d0c00af64d5c388f837
#
#                                product_category_name  product_weight_g  \
# 5703   portateis_cozinha_e_preparadores_de_alimentos            1200.0
# 7176   portateis_cozinha_e_preparadores_de_alimentos            1200.0
# 8647   portateis_cozinha_e_preparadores_de_alimentos             850.0
# 10822  portateis_cozinha_e_preparadores_de_alimentos            1200.0
# 13995  portateis_cozinha_e_preparadores_de_alimentos           10600.0
# 15874  portateis_cozinha_e_preparadores_de_alimentos             750.0
# ...

# %%
df_merged['product_category_name'] = df_merged['product_category_name_english']
df_merged
# Out:
#                              product_id      product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                  perfumery
# 1      3aa071139cb16b67ca9e5dea641aaa2f                        art
# 2      96bd76ec8810374ed1b65e291975717f             sports_leisure
# 3      cef67bcfe19066a932b7673e239eb23d                       baby
# 4      9dc1a7de274444849c219cff195d0b71                 housewares
# ...                                 ...                        ...
# 32335  a0b7d5a992ccda646f2d34e418fff5a0            furniture_decor
# 32336  bf4538d88321d0fd4412a93c974510e6  construction_tools_lights
# 32337  9a7c6041fa9592d9d9ef6cfe62a71f8c             bed_bath_table
# 32338  83808703fc0706a22e264b9d75f04a2e      computers_accessories
# 32339  106392145fca363410d287a815be6de4             bed_bath_table
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 0                 225.0               16.0               10.0
# ...

# %%
df_merged = df_merged.drop('product_category_name_english', axis=1)
df_merged
# Out:
#                              product_id      product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                  perfumery
# 1      3aa071139cb16b67ca9e5dea641aaa2f                        art
# 2      96bd76ec8810374ed1b65e291975717f             sports_leisure
# 3      cef67bcfe19066a932b7673e239eb23d                       baby
# 4      9dc1a7de274444849c219cff195d0b71                 housewares
# ...                                 ...                        ...
# 32335  a0b7d5a992ccda646f2d34e418fff5a0            furniture_decor
# 32336  bf4538d88321d0fd4412a93c974510e6  construction_tools_lights
# 32337  9a7c6041fa9592d9d9ef6cfe62a71f8c             bed_bath_table
# 32338  83808703fc0706a22e264b9d75f04a2e      computers_accessories
# 32339  106392145fca363410d287a815be6de4             bed_bath_table
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 0                 225.0               16.0               10.0
# ...

# %%
df_merged.describe()
# Out:
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32340.000000       32340.000000       32340.000000
# mean        2276.956586          30.854545          16.958813
# std         4279.291845          16.955965          13.636115
# min            0.000000           7.000000           2.000000
# 25%          300.000000          18.000000           8.000000
# 50%          700.000000          25.000000          13.000000
# 75%         1900.000000          38.000000          21.000000
# max        40425.000000         105.000000         105.000000
#
#        product_width_cm
# count      32340.000000
# mean          23.208596
# std           12.078762
# min            6.000000
# 25%           15.000000
# 50%           20.000000
# 75%           30.000000
# max          118.000000

# %%
duplicatedRows = df_merged[df_merged.duplicated('product_id')]

# %%
print(duplicatedRows)
# Out:
# Empty DataFrame
# Columns: [product_id, product_category_name, product_weight_g, product_length_cm, product_height_cm, product_width_cm]
# Index: []

# %%
df_merged.set_index('product_id', inplace=True)
df_merged
# Out:
#                                       product_category_name  product_weight_g  \
# product_id
# 1e9e8ef04dbcff4541ed26657ea517e5                  perfumery             225.0
# 3aa071139cb16b67ca9e5dea641aaa2f                        art            1000.0
# 96bd76ec8810374ed1b65e291975717f             sports_leisure             154.0
# cef67bcfe19066a932b7673e239eb23d                       baby             371.0
# 9dc1a7de274444849c219cff195d0b71                 housewares             625.0
# ...                                                     ...               ...
# a0b7d5a992ccda646f2d34e418fff5a0            furniture_decor           12300.0
# bf4538d88321d0fd4412a93c974510e6  construction_tools_lights            1700.0
# 9a7c6041fa9592d9d9ef6cfe62a71f8c             bed_bath_table            1400.0
# 83808703fc0706a22e264b9d75f04a2e      computers_accessories             700.0
# 106392145fca363410d287a815be6de4             bed_bath_table            2083.0
#
# ...

# %%
df_merged.to_csv('./dbt_ecomm/seeds/clean_olist_products.csv', index=True)
